# %% [markdown]
# # The Shape of Uncertainty

# %% [markdown]
# This notebook explores how probability moves from discrete outcomes to continuous values, and how the shape of data, its probability distribution, helps us understand and quantify uncertainty.
